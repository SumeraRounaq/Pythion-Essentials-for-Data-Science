# %% [markdown]
# # Basics Of Python

# %% [markdown]
# ## In this video we will discuss

# %% [markdown]
# - Various Datatypes
# - Variables
# - Variable Assignment
# - Print Formatting

# %%
conda install -c conda-forge jupyter_contrib_nbextensions
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\numai\anaconda3
#
#   added / updated specs:
#     - jupyter_contrib_nbextensions
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.1               |   py38haa244fe_0         3.1 MB  conda-forge
#     jupyter_contrib_core-0.3.3 |             py_2          15 KB  conda-forge
#     jupyter_contrib_nbextensions-0.5.1|     pyhd8ed1ab_2        19.5 MB  conda-forge
#     jupyter_highlight_selected_word-0.2.0|py38haa244fe_1002          15 KB  conda-forge
#     jupyter_latex_envs-1.4.6   |  pyhd8ed1ab_1002         735 KB  conda-forge
#     jupyter_nbextensions_configurator-0.4.1|   py38haa244fe_2         491 KB  conda-forge
#     python_abi-3.8             |           1_cp38           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        23.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   jupyter_contrib_c~ conda-forge/noarch::jupyter_contrib_core-0.3.3-py_2
#   jupyter_contrib_n~ conda-forge/noarch::jupyter_contrib_nbextensions-0.5.1-pyhd8ed1ab_2
#   jupyter_highlight~ conda-forge/win-64::jupyter_highlight_selected_word-0.2.0-py38haa244fe_1002
#   jupyter_latex_envs conda-forge/noarch::jupyter_latex_envs-1.4.6-pyhd8ed1ab_1002
#   jupyter_nbextensi~ conda-forge/win-64::jupyter_nbextensions_configurator-0.4.1-py38haa244fe_2
#   python_abi         conda-forge/win-64::python_abi-3.8-1_cp38
#
# The following packages will be UPDATED:
#
#   conda               pkgs/main::conda-4.9.2-py38haa95532_0 --> conda-forge::conda-4.10.1-py38haa244fe_0
#
#
#
# Downloading and Extracting Packages
#
# jupyter_nbextensions | 491 KB    |            |   0%
# jupyter_nbextensions | 491 KB    | 3          |   3%
# jupyter_nbextensions | 491 KB    | ########## | 100%
# jupyter_nbextensions | 491 KB    | ########## | 100%
#
# conda-4.10.1         | 3.1 MB    |            |   0%
# conda-4.10.1         | 3.1 MB    | #1         |  11%
# conda-4.10.1         | 3.1 MB    | #9         |  19%
# conda-4.10.1         | 3.1 MB    | ##7        |  28%
# conda-4.10.1         | 3.1 MB    | ###6       |  36%
# conda-4.10.1         | 3.1 MB    | ####4      |  44%
# conda-4.10.1         | 3.1 MB    | #####2     |  53%
# conda-4.10.1         | 3.1 MB    | ######     |  61%
# conda-4.10.1         | 3.1 MB    | ######9    |  69%
# conda-4.10.1         | 3.1 MB    | #######2   |  72%
# conda-4.10.1         | 3.1 MB    | #######5   |  75%
# conda-4.10.1         | 3.1 MB    | #######8   |  78%
# conda-4.10.1         | 3.1 MB    | ########1  |  81%
# conda-4.10.1         | 3.1 MB    | ########4  |  84%
# conda-4.10.1         | 3.1 MB    | ########7  |  87%
# conda-4.10.1         | 3.1 MB    | #########  |  91%
# conda-4.10.1         | 3.1 MB    | #########8 |  98%
# conda-4.10.1         | 3.1 MB    | ########## | 100%
#
# jupyter_highlight_se | 15 KB     |            |   0%
# jupyter_highlight_se | 15 KB     | ########## | 100%
# jupyter_highlight_se | 15 KB     | ########## | 100%
#
# jupyter_latex_envs-1 | 735 KB    |            |   0%
# jupyter_latex_envs-1 | 735 KB    | ##6        |  26%
# jupyter_latex_envs-1 | 735 KB    | ####3      |  44%
# jupyter_latex_envs-1 | 735 KB    | ######5    |  65%
# jupyter_latex_envs-1 | 735 KB    | ########## | 100%
# jupyter_latex_envs-1 | 735 KB    | ########## | 100%
#
# jupyter_contrib_core | 15 KB     |            |   0%
# jupyter_contrib_core | 15 KB     | ########## | 100%
# jupyter_contrib_core | 15 KB     | ########## | 100%
#
# jupyter_contrib_nbex | 19.5 MB   |            |   0%
# jupyter_contrib_nbex | 19.5 MB   | 1          |   1%
# jupyter_contrib_nbex | 19.5 MB   | 3          |   3%
# jupyter_contrib_nbex | 19.5 MB   | 4          |   4%
# jupyter_contrib_nbex | 19.5 MB   | 5          |   6%
# jupyter_contrib_nbex | 19.5 MB   | 6          |   7%
# jupyter_contrib_nbex | 19.5 MB   | 8          |   9%
# jupyter_contrib_nbex | 19.5 MB   | 9          |  10%
# jupyter_contrib_nbex | 19.5 MB   | #1         |  11%
# jupyter_contrib_nbex | 19.5 MB   | #1         |  12%
# jupyter_contrib_nbex | 19.5 MB   | #2         |  13%
# jupyter_contrib_nbex | 19.5 MB   | #3         |  13%
# jupyter_contrib_nbex | 19.5 MB   | #3         |  14%
# jupyter_contrib_nbex | 19.5 MB   | #4         |  14%
# jupyter_contrib_nbex | 19.5 MB   | #5         |  15%
# jupyter_contrib_nbex | 19.5 MB   | #5         |  16%
# jupyter_contrib_nbex | 19.5 MB   | #6         |  16%
# jupyter_contrib_nbex | 19.5 MB   | #6         |  17%
# jupyter_contrib_nbex | 19.5 MB   | #7         |  17%
# jupyter_contrib_nbex | 19.5 MB   | #7         |  17%
# jupyter_contrib_nbex | 19.5 MB   | #8         |  18%
# jupyter_contrib_nbex | 19.5 MB   | #8         |  19%
# jupyter_contrib_nbex | 19.5 MB   | #9         |  19%
# jupyter_contrib_nbex | 19.5 MB   | #9         |  20%
# jupyter_contrib_nbex | 19.5 MB   | ##         |  20%
# jupyter_contrib_nbex | 19.5 MB   | ##         |  21%
# jupyter_contrib_nbex | 19.5 MB   | ##1        |  21%
# jupyter_contrib_nbex | 19.5 MB   | ##1        |  22%
# jupyter_contrib_nbex | 19.5 MB   | ##2        |  22%
# jupyter_contrib_nbex | 19.5 MB   | ##2        |  23%
# jupyter_contrib_nbex | 19.5 MB   | ##3        |  23%
# jupyter_contrib_nbex | 19.5 MB   | ##3        |  24%
# jupyter_contrib_nbex | 19.5 MB   | ##4        |  24%
# jupyter_contrib_nbex | 19.5 MB   | ##4        |  25%
# jupyter_contrib_nbex | 19.5 MB   | ##5        |  25%
# jupyter_contrib_nbex | 19.5 MB   | ##5        |  26%
# jupyter_contrib_nbex | 19.5 MB   | ##6        |  26%
# jupyter_contrib_nbex | 19.5 MB   | ##6        |  27%
# jupyter_contrib_nbex | 19.5 MB   | ##7        |  28%
# jupyter_contrib_nbex | 19.5 MB   | ##8        |  28%
# jupyter_contrib_nbex | 19.5 MB   | ##8        |  29%
# jupyter_contrib_nbex | 19.5 MB   | ##9        |  29%
# jupyter_contrib_nbex | 19.5 MB   | ##9        |  30%
# jupyter_contrib_nbex | 19.5 MB   | ###        |  30%
# jupyter_contrib_nbex | 19.5 MB   | ###        |  31%
# jupyter_contrib_nbex | 19.5 MB   | ###1       |  31%
# jupyter_contrib_nbex | 19.5 MB   | ###1       |  32%
# jupyter_contrib_nbex | 19.5 MB   | ###2       |  32%
# jupyter_contrib_nbex | 19.5 MB   | ###2       |  33%
# jupyter_contrib_nbex | 19.5 MB   | ###3       |  33%
# jupyter_contrib_nbex | 19.5 MB   | ###3       |  34%
# jupyter_contrib_nbex | 19.5 MB   | ###4       |  34%
# jupyter_contrib_nbex | 19.5 MB   | ###4       |  35%
# jupyter_contrib_nbex | 19.5 MB   | ###5       |  35%
# jupyter_contrib_nbex | 19.5 MB   | ###5       |  36%
# jupyter_contrib_nbex | 19.5 MB   | ###6       |  37%
# jupyter_contrib_nbex | 19.5 MB   | ###6       |  37%
# jupyter_contrib_nbex | 19.5 MB   | ###7       |  38%
# jupyter_contrib_nbex | 19.5 MB   | ###8       |  38%
# jupyter_contrib_nbex | 19.5 MB   | ###8       |  39%
# jupyter_contrib_nbex | 19.5 MB   | ###9       |  39%
# jupyter_contrib_nbex | 19.5 MB   | ###9       |  40%
# jupyter_contrib_nbex | 19.5 MB   | ####       |  41%
# jupyter_contrib_nbex | 19.5 MB   | ####1      |  41%
# jupyter_contrib_nbex | 19.5 MB   | ####1      |  42%
# jupyter_contrib_nbex | 19.5 MB   | ####2      |  42%
# Note: you may need to restart the kernel to use updated packages.
# jupyter_contrib_nbex | 19.5 MB   | ####2      |  43%
# jupyter_contrib_nbex | 19.5 MB   | ####3      |  43%
# jupyter_contrib_nbex | 19.5 MB   | ####3      |  44%
# jupyter_contrib_nbex | 19.5 MB   | ####4      |  44%
# jupyter_contrib_nbex | 19.5 MB   | ####4      |  45%
# jupyter_contrib_nbex | 19.5 MB   | ####5      |  45%
# jupyter_contrib_nbex | 19.5 MB   | ####5      |  46%
# jupyter_contrib_nbex | 19.5 MB   | ####6      |  46%
# jupyter_contrib_nbex | 19.5 MB   | ####6      |  47%
# jupyter_contrib_nbex | 19.5 MB   | ####7      |  47%
# jupyter_contrib_nbex | 19.5 MB   | ####7      |  48%
# jupyter_contrib_nbex | 19.5 MB   | ####8      |  48%
# jupyter_contrib_nbex | 19.5 MB   | ####8      |  49%
# jupyter_contrib_nbex | 19.5 MB   | ####9      |  49%
# jupyter_contrib_nbex | 19.5 MB   | ####9      |  50%
# jupyter_contrib_nbex | 19.5 MB   | #####      |  50%
# jupyter_contrib_nbex | 19.5 MB   | #####      |  51%
# jupyter_contrib_nbex | 19.5 MB   | #####1     |  51%
# jupyter_contrib_nbex | 19.5 MB   | #####1     |  52%
# jupyter_contrib_nbex | 19.5 MB   | #####2     |  52%
# jupyter_contrib_nbex | 19.5 MB   | #####2     |  53%
# jupyter_contrib_nbex | 19.5 MB   | #####3     |  53%
# jupyter_contrib_nbex | 19.5 MB   | #####3     |  54%
# jupyter_contrib_nbex | 19.5 MB   | #####4     |  55%
# jupyter_contrib_nbex | 19.5 MB   | #####5     |  55%
# jupyter_contrib_nbex | 19.5 MB   | #####5     |  56%
# jupyter_contrib_nbex | 19.5 MB   | #####6     |  56%
# jupyter_contrib_nbex | 19.5 MB   | #####6     |  57%
# jupyter_contrib_nbex | 19.5 MB   | #####7     |  57%
# jupyter_contrib_nbex | 19.5 MB   | #####7     |  58%
# jupyter_contrib_nbex | 19.5 MB   | #####8     |  58%
# jupyter_contrib_nbex | 19.5 MB   | #####8     |  59%
# jupyter_contrib_nbex | 19.5 MB   | #####9     |  59%
# jupyter_contrib_nbex | 19.5 MB   | #####9     |  60%
# jupyter_contrib_nbex | 19.5 MB   | ######     |  60%
# jupyter_contrib_nbex | 19.5 MB   | ######     |  61%
# jupyter_contrib_nbex | 19.5 MB   | ######1    |  61%
# jupyter_contrib_nbex | 19.5 MB   | ######1    |  62%
# jupyter_contrib_nbex | 19.5 MB   | ######2    |  62%
# jupyter_contrib_nbex | 19.5 MB   | ######2    |  63%
# jupyter_contrib_nbex | 19.5 MB   | ######3    |  63%
# jupyter_contrib_nbex | 19.5 MB   | ######3    |  64%
# jupyter_contrib_nbex | 19.5 MB   | ######4    |  64%
# jupyter_contrib_nbex | 19.5 MB   | ######4    |  65%
# jupyter_contrib_nbex | 19.5 MB   | ######5    |  65%
# jupyter_contrib_nbex | 19.5 MB   | ######5    |  66%
# jupyter_contrib_nbex | 19.5 MB   | ######6    |  66%
# jupyter_contrib_nbex | 19.5 MB   | ######6    |  67%
# jupyter_contrib_nbex | 19.5 MB   | ######7    |  67%
# jupyter_contrib_nbex | 19.5 MB   | ######7    |  68%
# jupyter_contrib_nbex | 19.5 MB   | ######8    |  68%
# jupyter_contrib_nbex | 19.5 MB   | ######8    |  69%
# jupyter_contrib_nbex | 19.5 MB   | ######9    |  69%
# jupyter_contrib_nbex | 19.5 MB   | ######9    |  70%
# jupyter_contrib_nbex | 19.5 MB   | #######    |  70%
# jupyter_contrib_nbex | 19.5 MB   | #######    |  71%
# jupyter_contrib_nbex | 19.5 MB   | #######1   |  71%
# jupyter_contrib_nbex | 19.5 MB   | #######1   |  72%
# jupyter_contrib_nbex | 19.5 MB   | #######2   |  72%
# jupyter_contrib_nbex | 19.5 MB   | #######2   |  73%
# jupyter_contrib_nbex | 19.5 MB   | #######3   |  73%
# jupyter_contrib_nbex | 19.5 MB   | #######3   |  74%
# jupyter_contrib_nbex | 19.5 MB   | #######4   |  74%
# jupyter_contrib_nbex | 19.5 MB   | #######4   |  75%
# jupyter_contrib_nbex | 19.5 MB   | #######5   |  75%
# jupyter_contrib_nbex | 19.5 MB   | #######6   |  76%
# jupyter_contrib_nbex | 19.5 MB   | #######7   |  77%
# jupyter_contrib_nbex | 19.5 MB   | #######7   |  78%
# jupyter_contrib_nbex | 19.5 MB   | #######8   |  78%
# jupyter_contrib_nbex | 19.5 MB   | #######8   |  79%
# jupyter_contrib_nbex | 19.5 MB   | #######9   |  79%
# jupyter_contrib_nbex | 19.5 MB   | #######9   |  80%
# jupyter_contrib_nbex | 19.5 MB   | ########   |  81%
# jupyter_contrib_nbex | 19.5 MB   | ########1  |  81%
# jupyter_contrib_nbex | 19.5 MB   | ########1  |  82%
# jupyter_contrib_nbex | 19.5 MB   | ########2  |  82%
# jupyter_contrib_nbex | 19.5 MB   | ########2  |  83%
# jupyter_contrib_nbex | 19.5 MB   | ########3  |  83%
# jupyter_contrib_nbex | 19.5 MB   | ########3  |  84%
# jupyter_contrib_nbex | 19.5 MB   | ########4  |  84%
# jupyter_contrib_nbex | 19.5 MB   | ########4  |  85%
# jupyter_contrib_nbex | 19.5 MB   | ########5  |  85%
# jupyter_contrib_nbex | 19.5 MB   | ########6  |  86%
# jupyter_contrib_nbex | 19.5 MB   | ########6  |  87%
# jupyter_contrib_nbex | 19.5 MB   | ########7  |  87%
# jupyter_contrib_nbex | 19.5 MB   | ########7  |  88%
# jupyter_contrib_nbex | 19.5 MB   | ########8  |  88%
# jupyter_contrib_nbex | 19.5 MB   | ########8  |  89%
# jupyter_contrib_nbex | 19.5 MB   | ########9  |  89%
# jupyter_contrib_nbex | 19.5 MB   | ########9  |  90%
# jupyter_contrib_nbex | 19.5 MB   | #########  |  90%
# jupyter_contrib_nbex | 19.5 MB   | #########  |  91%
# jupyter_contrib_nbex | 19.5 MB   | #########1 |  91%
# jupyter_contrib_nbex | 19.5 MB   | #########1 |  91%
# jupyter_contrib_nbex | 19.5 MB   | #########1 |  92%
# jupyter_contrib_nbex | 19.5 MB   | #########2 |  92%
# jupyter_contrib_nbex | 19.5 MB   | #########3 |  93%
# jupyter_contrib_nbex | 19.5 MB   | #########3 |  94%
# jupyter_contrib_nbex | 19.5 MB   | #########4 |  94%
# jupyter_contrib_nbex | 19.5 MB   | #########4 |  95%
# jupyter_contrib_nbex | 19.5 MB   | #########5 |  95%
# jupyter_contrib_nbex | 19.5 MB   | #########5 |  95%
# jupyter_contrib_nbex | 19.5 MB   | #########5 |  96%
# jupyter_contrib_nbex | 19.5 MB   | #########6 |  96%
# jupyter_contrib_nbex | 19.5 MB   | #########7 |  97%
# jupyter_contrib_nbex | 19.5 MB   | #########7 |  98%
# jupyter_contrib_nbex | 19.5 MB   | #########8 |  98%
# jupyter_contrib_nbex | 19.5 MB   | #########9 |  99%
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# jupyter_contrib_nbex | 19.5 MB   | #########9 | 100%
# jupyter_contrib_nbex | 19.5 MB   | #########9 | 100%
# jupyter_contrib_nbex | 19.5 MB   | ########## | 100%
#
# python_abi-3.8       | 4 KB      |            |   0%
# python_abi-3.8       | 4 KB      | ########## | 100%
# python_abi-3.8       | 4 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
# Enabling: jupyter_nbextensions_configurator
# - Writing config: C:\Users\numai\anaconda3\etc\jupyter
#     - Validating...
#       jupyter_nbextensions_configurator 0.4.1 ok
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...
#
# done

# %%
$ conda update -n base -c defaults conda
# Out:
#   File "<ipython-input-2-2d828a44dfb1>", line 1
#     $ conda update -n base -c defaults conda
#     ^
# SyntaxError: invalid syntax

# %%
jupyter nbextensions_configurator enable --user
# Out:
#   File "<ipython-input-1-421ebaa84054>", line 1
#     jupyter nbextensions_configurator enable --user
#             ^
# SyntaxError: invalid syntax
